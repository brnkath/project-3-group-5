# %%
# Dependencies
import pandas as pd
import os

# %%
# Import CSV file
# If we move these files, remember to update this to path properly - LAB
file_path = 'per_capita_income-miami-dade20231011.csv'

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
# List everything in the header row (column names)
header_row = df.columns.tolist()
header_row
# Out:
# ['Indicator Name',
#  'What Is This Indicator',
#  'Location Type',
#  'Location',
#  'Indicator Rate Value',
#  'Indicator Rate Value Units',
#  'Rate Lower Confidence Interval',
#  'Rate Upper Confidence Interval',
#  'Indicator Count Value',
#  'Indicator Count Value Units',
#  'Count Lower Confidence Interval',
#  'Count Upper Confidence Interval',
#  'Indicator Value Unstable',
#  'Period of Measure',
#  'Data Source',
#  'Technical Note',
#  'Breakout Title',
#  'Breakout Category',
#  'Breakout Subcategory',
#  'Breakout Rate Value',
#  'Breakout Rate Value Units',
#  'Breakout Rate Lower Confidence Interval',
#  'Breakout Rate Upper Confidence Interval',
#  'Breakout Count Value',
#  'Breakout Count Value Units',
#  'Breakout Count Lower Confidence Interval',
#  'Breakout Count Upper Confidence Interval',
#  'Breakout Unstable',
#  'Breakout Footer']

# %%
# Create a new DataFrame with selected columns
selected_columns = df[["Location Type", "Location", "Indicator Rate Value", "Indicator Rate Value Units", "Rate Lower Confidence Interval", "Rate Upper Confidence Interval"]]

# %%
# Display the selected columns, modified DF
selected_columns
# Out:
#     Location Type  Location  Indicator Rate Value Indicator Rate Value Units  \
# 0        Zip Code     33010                 19823                    dollars
# 1        Zip Code     33010                 18011                    dollars
# 2        Zip Code     33010                 17092                    dollars
# 3        Zip Code     33010                 15462                    dollars
# 4        Zip Code     33010                 14086                    dollars
# ..            ...       ...                   ...                        ...
# 857      Zip Code     33196                 23582                    dollars
# 858      Zip Code     33196                 24049                    dollars
# 859      Zip Code     33196                 23687                    dollars
# 860      Zip Code     33196                 23745                    dollars
# 861      Zip Code     33196                 23614                    dollars
#
# ...

# %%
# Rename the 'Location' to 'ZipCode'
df = df.rename(columns={'Location': 'ZipCode'})

# %%
# Create a new DataFrame with selected columns, including renamed ZipCode
selected_columns = df[["ZipCode", "Indicator Rate Value", "Indicator Rate Value Units", "Rate Lower Confidence Interval", "Rate Upper Confidence Interval"]]

# %%
# Display the selected columns
selected_columns
# Out:
#      ZipCode  Indicator Rate Value Indicator Rate Value Units  \
# 0      33010                 19823                    dollars
# 1      33010                 18011                    dollars
# 2      33010                 17092                    dollars
# 3      33010                 15462                    dollars
# 4      33010                 14086                    dollars
# ..       ...                   ...                        ...
# 857    33196                 23582                    dollars
# 858    33196                 24049                    dollars
# 859    33196                 23687                    dollars
# 860    33196                 23745                    dollars
# 861    33196                 23614                    dollars
#
#      Rate Lower Confidence Interval  Rate Upper Confidence Interval
# 0                             18798                           20848
# 1                             16951                           19071
# ...
