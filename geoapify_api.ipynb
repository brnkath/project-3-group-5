# %%
# Dependencies
import requests
import pandas as pd
import json
import csv

# Import geoapify key
from config import geoapify_key

# %%
url = "https://api.geoapify.com/v2/places?categories=catering.restaurant,commercial.supermarket,catering.fast_food&filter=place:517ff62345640c54c059e773493030c63940f00101f9010191120000000000c002089203054d69616d69&lang=en&limit=500&apiKey=" + geoapify_key

# %%
response = requests.get(url)

# %%
json_response = response.json()

# %%
json_result = json.dumps(json_response, indent=2)

# %%
print(json_result)
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "name": "Mario the Baker Pizza",
#         "country": "United States",
#         "country_code": "us",
#         "state": "Florida",
#         "county": "Miami-Dade County",
#         "city": "Miami",
#         "postcode": "33128",
#         "street": "West Flagler Street",
#         "housenumber": "43",
#         "lon": -80.19447087596217,
#         "lat": 25.77436085,
#         "state_code": "FL",
#         "formatted": "Mario the Baker Pizza, 43 West Flagler Street, Miami, FL 33128, United States of America",
#         "address_line1": "Mario the Baker Pizza",
#         "address_line2": "43 West Flagler Street, Miami, FL 33128, United States of America",
#         "categories": [
#           "catering",
#           "catering.restaurant",
#           "catering.restaurant.pizza"
#         ],
#         "details": [
#           "details",
# ...

# %%
# Output JSON file
with open("resources/locations.json", "w") as outfile:
  outfile.write(json_result)

# %%
# Import JSON file and convert it to a DataFrame
with open("resources/locations.json") as f:
  # json_data = json.load(f)
  locations_df = pd.read_json(f)

# locations_df = pd.read_json(json_data)

locations_df.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Ma...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Ji...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Ca...
# 3  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Mo...
# 4  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Am...

# %%
# Write json data to csv
csv_writer - csv.writer(json_result)

count = 0
for data in json
